# %% [markdown]
# # Demo of the Library Sandbox

# %%
from src.sum_impact_assessment.utils.tools import load_living_labs_from_file, load_measures_from_file, load_kpis_from_file, load_kpi_groups_from_file
from src.sum_impact_assessment.utils.kpi_normalizer import KPINormalizer
from src.sum_impact_assessment.models import KPIImpactAnalyzer

measures = load_measures_from_file('data/measures.json')
kpis = load_kpis_from_file('data/kpis.json')
kpi_groups = load_kpi_groups_from_file(
    'data/kpi_groups.json', kpi_definitions=kpis)
living_labs = load_living_labs_from_file(
    'data/living_labs_data.json', kpi_definitions=kpis)


print("KPIs", "-" * 40)
print("Number of kpis : ", len(kpis))
print("Number of kpis groups: ", len(kpi_groups))

print("Number of living labs : ", len(living_labs))
for lab in living_labs:
    print(f"ID: {lab.id}")
    print(f"Name: {lab.name}")
    print(f"Number of KPIs: {len(lab.kpis)}")
    print(f"Number of Measures: {len(lab.measures)}")

    lab.kpis = KPINormalizer(lab.kpis).normalizeKPIs()
    print("-" * 40)

analyzer = KPIImpactAnalyzer(living_labs, measures, kpis, kpi_groups)
group_results = analyzer.run_analysis_group(kpi_groups[0]) # Test group

print("MEASURES AFTER ANALYSIS", "-" * 40)
print(f"MSQ Error: {group_results.msqe}")
print("Number of measures : ", len(measures))
for measure in group_results.measure_coefficients:
    print(f"ID: {measure.id}")
    print(f"Name: {measure.name}")
    print(f"Coeff: {measure.coefficient}")
    print("-" * 40)

#analyzer.run_analysis() # NOTE This won't run until all KPIs have upper and lower bounds
# Out:
# KPIs ----------------------------------------
# Number of kpis :  44
# Number of kpis groups:  13
# Number of living labs :  9
# ID: lab_munich
# Name: Munich
# Number of KPIs: 42
# Number of Measures: 14
# ----------------------------------------
# ID: lab_geneva
# Name: Geneva
# Number of KPIs: 28
# Number of Measures: 10
# ----------------------------------------
# ID: lab_jerusalem
# Name: Jerusalem
# Number of KPIs: 29
# Number of Measures: 13
# ----------------------------------------
# ID: lab_athens_penteli
# Name: Penteli
# Number of KPIs: 34
# Number of Measures: 8
# ----------------------------------------
# ID: lab_rotterdam
# Name: Rotterdam
# Number of KPIs: 30
# Number of Measures: 9
# ----------------------------------------
# ID: lab_krakow
# Name: Krakow
# Number of KPIs: 31
# Number of Measures: 9
# ----------------------------------------
# ID: lab_fredrikstad
# Name: Fredrikstad
# Number of KPIs: 0
# Number of Measures: 11
# ----------------------------------------
# ID: lab_larnaca
# Name: Larnaca
# Number of KPIs: 25
# Number of Measures: 4
# ----------------------------------------
# ID: lab_coimbra
# Name: Coimbra
# Number of KPIs: 32
# Number of Measures: 8
# ----------------------------------------
# MEASURES AFTER ANALYSIS ----------------------------------------
# MSQ Error: 0.050274671478090185
# Number of measures :  20
# ID: measure_001
# Name: Congestion charges
# Coeff: -0.16200991903161166
# ----------------------------------------
# ID: measure_002
# Name: Parking charges
# Coeff: 0.28509392465054884
# ----------------------------------------
# ID: measure_003
# Name: Restricted parking
# Coeff: -0.009481943821532847
# ----------------------------------------
# ID: measure_004
# Name: Limited traffic zone / Pedestrianisation of streets
# Coeff: -0.2378705895529405
# ----------------------------------------
# ID: measure_005
# Name: Parking supply management
# Coeff: 0.23030083706358342
# ----------------------------------------
# ID: measure_006
# Name: Speed limits
# Coeff: -0.016065330951494705
# ----------------------------------------
# ID: measure_007
# Name: Mobility hubs (see task T3.2)
# Coeff: -0.03295249788334063
# ----------------------------------------
# ID: measure_008
# Name: Scheduling integration in MaaS services (see task T2.3)
# Coeff: 0.1956588077217793
# ----------------------------------------
# ID: measure_009
# Name: Ticketing integration in MaaS services (see task T3.4)
# Coeff: -0.22645711202143076
# ----------------------------------------
# ID: measure_010
# Name: Improved NSM infrastructure, e.g. bike lanes & "park & ride"
# Coeff: -0.055537450694846134
# ----------------------------------------
# ID: measure_011
# Name: On demand vehicle sharing action plan
# Coeff: 0.21429927138203975
# ----------------------------------------
# ID: measure_012
# Name: Nudging (gamification or rewards)
# Coeff: -0.0800437904831061
# ----------------------------------------
# ID: measure_013
# Name: Dynamic pricing of NSM
# Coeff: 0.34865551639006576
# ----------------------------------------
# ID: measure_014
# Name: Improved information about the availability of shared modes
# Coeff: -0.038650283763000275
# ----------------------------------------
# ID: measure_015
# Name: Introduction of new NSM services (ex. bike-sharing)
# Coeff: -0.15782679906983374
# ----------------------------------------
# ID: measure_016
# Name: Introduction of new PT infrastructures/lines (ex. e-buses, LRT)
# Coeff: -0.2812501996083959
# ----------------------------------------
# ID: measure_017
# Name: Streets retrofitting/introduction of priority lanes
# Coeff: 0.46460992854836314
# ----------------------------------------
# ID: measure_018
# Name: Dedicated parking spaces for carsharing/micromobility
# Coeff: -0.016065330951494705
# ----------------------------------------
# ID: measure_019
# Name: Widening PT geographical area
# Coeff: 0.23030083706358342
# ----------------------------------------
# ID: measure_020
# Name: Central PT planning and construction program
# Coeff: 0.23030083706358342
# ----------------------------------------
